# %% [markdown]
# # Informations
#
# University of Zurich, <br>
# Network Science, <br>
# Assignment 2
#
# Pietro Bonazzi, <br>
# LEGI 17-200-635, <br>
# pietro.bonazzi@uzh.ch

# %% [markdown]
# # Libraries

# %%
# %run functions_02.ipynb

# %% [markdown]
# # A02.1 Average degree of the nearest neighbours
#
# Task: For each dataset 𝒢, randomise it to obtain a network 𝒢𝑟𝑛𝑑 and explore their assortativity* properties
#
# *Is there homophily in the network? (nodes connect to others similar to them?)
#
# 1. Plot the average degree of the nearest neighbours 𝑘𝑛𝑛(𝑘) as a function of the vertices degree 𝑘
# 2. Compute the assortativity coefficient of the real network
# 3. Compute the assortativity coefficient of the randomised network

# %%
from os import walk
def all_files(path) :
    names = []
    for files in walk(path):
        names.append(files)
    return names[0][2]

folder="Data/2/data"
filenames=all_files(folder)

# %%
print(filenames)
# Out:
# ['graph_jazz_collab.gml', 'graph_eu_airlines.gml', 'graph_CondMat.gml', 'graph_internet.gml', 'graph_AstroPh.gml', 'graph_facebook.gml', 'graph_terrorists.gml', 'graph_dolphins.gml', 'graph_chess.gml', 'graph_game_thrones.gml', 'graph_florentine_families.gml', 'graph_celegansInteractomes.gml']

# %%
for i in range(len(filenames)) :
    graph = nx.read_gml("Data/2/data/"+filenames[i])
    num = graph.number_of_nodes()
    grnd = nx.algorithms.swap.double_edge_swap(graph, nswap=num, max_tries=num*3)
    plot_avg_degree_NnVd(graph, filenames[i])
    print("Assortativity coeff of ", filenames[i], " : ", compute_assortativity_coeff(graph))
    print("Assortativity coeff of ", filenames[i], " randomised : ", compute_assortativity_coeff(grnd))
# Out:
# Assortativity coeff of  graph_jazz_collab.gml  :  -0.012680722122915643
# Assortativity coeff of  graph_jazz_collab.gml  randomised :  -0.012680722122915643
# Assortativity coeff of  graph_eu_airlines.gml  :  -0.15749387478597102
# Assortativity coeff of  graph_eu_airlines.gml  randomised :  -0.15749387478597102
# Assortativity coeff of  graph_CondMat.gml  :  0.07617172050974347
# Assortativity coeff of  graph_CondMat.gml  randomised :  0.07617172050974347
# Assortativity coeff of  graph_internet.gml  :  -0.19949468783517302
# Assortativity coeff of  graph_internet.gml  randomised :  -0.19949468783517302
# Assortativity coeff of  graph_AstroPh.gml  :  0.16532954009078618
# Assortativity coeff of  graph_AstroPh.gml  randomised :  0.16532954009078618
# Assortativity coeff of  graph_facebook.gml  :  0.05409104225098741
# Assortativity coeff of  graph_facebook.gml  randomised :  0.05409104225098741
# Assortativity coeff of  graph_terrorists.gml  :  -0.17642359874590582
# Assortativity coeff of  graph_terrorists.gml  randomised :  -0.17642359874590582
# Assortativity coeff of  graph_dolphins.gml  :  0.011286125188330647
# Assortativity coeff of  graph_dolphins.gml  randomised :  0.011286125188330647
# Assortativity coeff of  graph_chess.gml  :  0.2791632196911812
# Assortativity coeff of  graph_chess.gml  randomised :  0.2791632196911812
# Assortativity coeff of  graph_game_thrones.gml  :  -0.13154323417547512
# Assortativity coeff of  graph_game_thrones.gml  randomised :  -0.13154323417547512
# Assortativity coeff of  graph_florentine_families.gml  :  0.002226179875334215
# Assortativity coeff of  graph_florentine_families.gml  randomised :  0.002226179875334215
# Assortativity coeff of  graph_celegansInteractomes.gml  :  0.11829298941322017
# Assortativity coeff of  graph_celegansInteractomes.gml  randomised :  0.11829298941322017

# %% [markdown]
# # A02.2 Clustering and randomisation
#
# For each dataset 𝒢, randomise it to obtain a network 𝒢𝑟𝑛𝑑 and explore their clustering properties
# 1. Plot the degree distribution in double-logscale and mark with a vertical line the average degree ⟨𝑘⟩
# 2. For each node, compute the clustering coefficient in the graphs 𝒢 (denoted by 𝐶(𝑖)) and 𝒢𝑟𝑛𝑑 (denoted as 𝐶𝑟𝑛𝑑(𝑖))
# 3. Do a scatter plot of 𝐶(𝑖) vs. 𝐶𝑟𝑛𝑑(𝑖)

# %%
for i in range(len(filenames)):
    graph = nx.read_gml("Data/2/data/"+filenames[i])
    degree_distrib(graph, filenames[i])
    num = graph.number_of_nodes()
    grnd = nx.algorithms.swap.double_edge_swap(graph, nswap=num, max_tries=num*3)
    c1=compute_clustering_coeff(graph)
    c2=compute_clustering_coeff(grnd)
    plot_clustering(c1, c2, filenames[i])
